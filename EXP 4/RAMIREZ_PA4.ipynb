# %% [markdown]
#  # ECE BOARD EXAM PROBLEM:

# %%
# To start our data structure, we call out panda first.
import pandas as pd

# To read the Excel file given, we use .read_excel() and print it.
board = pd.read_excel('board2.xlsx')
board
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication
# 0              78
# 1              52
# 2              57
# 3              68
# 4              88
# 5              83
# 6              48
# 7              53
# 8              42
# 9              44
# 10             67
# 11             64
# 12             43
# 13             73
# 14             86
# 15             81
# 16             45
# 17             52
# 18             71
# 19             85
# 20             72
# 21             58
# 22             47
# 23             41
# 24             42
# 25             62
# 26             86
# 27             53
# 28             62
# 29             56

# %%
# To only find the people who are > 70 in Math and whose hometown is Visayas, use .loc[] and print it.
Vis = board.loc[(board['Math']>70)&(board['Hometown']=='Visayas'), ['Name', 'Gender', 'Track', 'Math']]
Vis
# Out:
#    Name  Gender             Track  Math
# 5    S6  Female  Microelectronics    88
# 11  S12    Male     Communication    89
# 17  S18    Male     Communication    81
# 20  S21  Female  Microelectronics    83
# 23  S24  Female  Microelectronics    85
# 25  S26  Female   Instrumentation    71
# 27  S28    Male     Communication    85

# %%
# Same as the previous item, we use .loc[] and find > 70 in Electronics and are in Luzon and print it.
Instru = board.loc[(board['Electronics']>70)&(board['Hometown']=='Luzon'), ['Name', 'GEAS', 'Electronics']]
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 4    S5    43           86
# 7    S8    64           81
# 13  S14    89           77
# 24  S25    94           91
# 29  S30    57           81

# %%
# The next we find the average that is >=55, their hometown is Mindanao, and their Gender is Female then print.
Mindy = board.loc[(board['Average']>=55)&(board['Hometown']=='Mindanao')&(board['Gender']=='Female'), ['Name', 'Track', 'Electronics']]
Mindy
# Out:
#    Name             Track  Electronics
# 1    S2     Communication           75
# 2    S3   Instrumentation           74
# 16  S17  Microelectronics           79
# 19  S20     Communication           60

# %%
# To create the visuals we first call out matplotlib.pyplot and seaborn.
import seaborn as sns
import matplotlib.pyplot as plt

# To create the visual of average grade by track, we use the following, then print.
sns.barplot(data = board, x='Track', y='Average')
plt.title('Average Grade by Track')
plt.show()

# Like the first, to create the visual of average grade by gender.
sns.boxplot(data = board ,x='Gender', y='Average')
plt.title('Average Grade by Gender')
plt.show()

# Likewise, for average grade by hometown, we also use the following.
sns.boxplot(data = board ,x='Hometown', y='Average')
plt.title('Average Grade by Hometown')
plt.show()

# %% [markdown]
# Name: Ramirez, Gav Wrangler A.
#
# Section: 2ECE-A
